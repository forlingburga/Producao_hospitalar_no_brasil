# %% [markdown]
# <a href="https://colab.research.google.com/github/forlingburga/Producao_hospitalar_no_brasil/blob/main/notebooks/producao_hospitalar_brasil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('producao_hospitalar_brasil.csv')
df.head()
# Out:
#            estado    regiao   ano  leitos_disponiveis  internacoes  \
# 0       Sao Paulo   Sudeste  2023               45000      1200000
# 1  Rio de Janeiro   Sudeste  2023               22000       650000
# 2    Minas Gerais   Sudeste  2023               25000       700000
# 3           Bahia  Nordeste  2023               15000       420000
# 4          Parana       Sul  2023               18000       480000
#
#    procedimentos_realizados  valor_total_reais
# 0                   3400000          850000000
# 1                   1800000          420000000
# 2                   1950000          460000000
# 3                   1150000          270000000
# 4                   1300000          310000000
